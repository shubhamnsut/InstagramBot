# %% [markdown]
# # Webdriver and time are imported and webdriver is initialized

# %%
from selenium import webdriver
import time 
driver= webdriver.Chrome(executable_path=r'C:\Users\shubh\OneDrive\Desktop\chromedriver')

# %%
driver.get('https://www.instagram.com/')
time.sleep(5)

# %% [markdown]
# # We login to instagram using chrome webdriver

# %%
##username entered
user_name = driver.find_element_by_name('username')
user_name.send_keys('your_username')

# %%
## password entered
user_password=driver.find_element_by_name('password')
user_password.send_keys('your_password')

# %%
## submiting login detail
login= driver.find_element_by_class_name('Igw0E')
login.click()
time.sleep(5)  ## here time in second is add to stop futher things to happen so that website is fully loaded

# %%
## selecting not now for save your login info 
login_info = driver.find_element_by_class_name('sqdOP')
login_info.click()
# time.sleep(3)  ## here time in second

# %% [markdown]
# # Closing the turn_of_notification

# %%
## Notification about Turn on notification  
Turn_on_notification  = driver.find_element_by_class_name('aOOlW')
Turn_on_notification.click()
time.sleep(2)  ## here time in second

# %% [markdown]
# # We search word food and get the list of Instagram handle with search result as Food

# %%
## food is searched
search = driver.find_element_by_class_name('XTCLo')
search.send_keys('food')
# time.sleep(3)

# %%
## name is access 
name = driver.find_element_by_class_name('fuqBx')
# from bs4 import BeautifulSoup as bs 
# data = bs(name.text)
data=name.text
# delete the element  
# clear = driver.find_element_by_class_name('aIYm8')
# clear.click()

# %%
print('....List of Instagram handle with search result as Food....')
print()
lst=data.split('\n')
count=1
for i in range(0,len(lst),2):
    if lst[i][0]=='#':
        lst[i] = lst[i].replace("#", "")
        print(count,")",lst[i])
        count+=1
        print()
        
    else:
        print(count,")",lst[i])
        count+=1
        print()
# Out:
# ....List of Instagram handle with search result as Food....
#
# 1 ) foodie_incarnate
#
# 2 ) the.food_cult
#
# 3 ) foodrush.recipe
#
# 4 ) food__station07
#
# 5 ) delhifoodwalks
#
# 6 ) yourfoodlab
#
# 7 ) food
#
# 8 ) street_food_chandigarh
#
# 9 ) food_maple05
#
# 10 ) delhifoodguide
#
# 11 ) iaintsharefood
#
# 12 ) Food_junc
#
# 13 ) 454,892,370 posts
#
# 14 ) Geneva Food Stories 🥄
#
# 15 ) Shiwangi Priya
#
# 16 ) Food Network
#
# 17 ) Shagun Mittal
#
# 18 ) Food Stain On Hands
#
# 19 ) VAISHNAVI|Delhi Food Blog
#
# 20 ) Chinese Food Obsession
#
# 21 ) FOOD FOOD FOOD
#
# 22 ) _shutter📸
#
# 23 ) PRAGYA | Food & Lifestyle
#
# 24 ) Taru-Reet | Food and Travel
#
# 25 ) Hemant || Foodie
#
# 26 ) ᖴoodᑭorn
#
# 27 ) Karan Dua
#
# 28 ) Diy Food & Tricks Tutorials!
#
# 29 ) Foodie
#
# 30 ) satshya | chumma cooking food
#
# 31 ) FOODGOD®
#
# 32 ) 267,909,230 posts
#
# 33 ) 194,612,434 posts
#
# 34 ) Food Inspector Biskoo
#
# 35 ) WFP | World Food Programme
#
# ...

# %%
search.clear()

# %% [markdown]
# ## So Delhi instagram account is searched

# %%
## So Delhi is searched 
search = driver.find_element_by_class_name('XTCLo')
search.send_keys('So Delhi')
## so delhi name is click
time.sleep(1)
name = driver.find_element_by_class_name('_7UhW9')
name.click()
driver.back()

# %% [markdown]
# # First following and then unfollowing the So Delhi Page

# %% [markdown]
# 1) To search for sodelhi page

# %%
## So Delhi is searched 
search = driver.find_element_by_class_name('XTCLo')
search.send_keys('So Delhi')
## so delhi name is click
time.sleep(1)
name = driver.find_element_by_class_name('_7UhW9')
name.click()

# %% [markdown]
# 2) To follow

# %%
follow_btn= driver.find_element_by_class_name('_5f5mN')
follow_btn.click() 
print('Account Followed')
# Out:
# Account Followed

# %% [markdown]
# 3) To unfollow

# %%
unfollow_btn=driver.find_element_by_class_name('_5f5mN')
unfollow_btn.click()
time.sleep(0.1)
unfollow_btn_confirmation=driver.find_element_by_class_name('aOOlW')
unfollow_btn_confirmation.click()
print('Account Unfollowed')
driver.back()
# Out:
# Account Unfollowed

# %% [markdown]
# # Search for first 300 username of follower on So Delhi page

# %% [markdown]
# ### sodelhi is search for 300 username

# %%
driver.get('https://www.instagram.com/')

# %%
## sodelhi is search 
search = driver.find_element_by_class_name('XTCLo')
search.send_keys('sodelhi')
time.sleep(1)
name = driver.find_element_by_class_name('_7UhW9')
name.click()

# %%
followers= driver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[2]/a')
followers.click()

# %%
print('..Top 300 follwers of sodelhi..')
followers = driver.find_elements_by_class_name('FPmhX')
for i in range(0,300,1):
    time.sleep(0.1)
    print(followers[i].text)
# Out:
# ..Top 300 follwers of sodelhi..
# ankursapra
# deli.cious4581
# _sheena.bhatia_
# rajkumarrehal
# __tusharkumar__
# _himanshi_gupta_99
# neha.t.gupta
# weddsetgo
# bhawnabhatiaa
# iampoojamathur
# chopraharshita
# higgs_singlet9
# mansi_singh022
# hritsanto
# thegrl_withcurves
# kambojboys0786
# saurabhparmaar
# studymbbsaiims
# infinityandbeyond_indore
# anupriti3681
# imbharatkashyap
# shubham.sr4
# ahmad_amity85
# perfectionist_.001
# bae_of_bengol
# _freaking_crazy12
# irru_shaikhh
# oye_simi
# anmol_agrawallll
# thenullface
# reshmataneja9
# shobhit_saprass
# wabisabbiii
# __nyali
# poojasah95
# bubbles.fartface
# thomascynta
# janmeshpatel__0713
# kaze_trends
# varun.sharma21
# chikku013
# beingaarav07
# kanahiya256
# shringibakers
# sharikzone_
# surya.khude.925
# mister.srivastava
# fashhut
# ananya.chauhan_
# shiva_singh835
# nehak.24
# isarth
# leena_14aquarian
# ayushi.gupta01
# kanishq_basoya_dellhii0001
# _delhiwalee_
# ms.pankajsingh2011
# georgereximperator
# ...

# %%
### foodtalkindia instagram page is search for 500 username

# %%
driver.get('https://www.instagram.com/')

# %%
## foodtalkindia is searched 
search = driver.find_element_by_class_name('XTCLo')
search.send_keys('foodtalkindia')
time.sleep(1)
name = driver.find_element_by_class_name('_7UhW9')
name.click()

# %%
followers= driver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[2]/a')
followers.click()

# %%
## To find the list of username 
print('..Top 500 follwers of foodtalkindia..')
followers = driver.find_elements_by_class_name('FPmhX')
for i in range(0,500,1):
#     print(is_followers)
#         if is_followers=='Follow':
        print(followers[i].text)
#         time.sleep(0.1)
# Out:
# ..Top 500 follwers of foodtalkindia..
# risezonicofficial
# elchampion_7
# s_a_y_a_n_t_a_n_i_g_h_o_s_h
# travelblogs_from.her
# xx__lax
# _iamsantha_the_nature_lover_
# rumaisa_78a
# isuzu453
# crazy_but_kanish
# aravinth5086
# pikac_hu6436
# chikku013
# ahmed_raxa67
# mr__street__burner
# ipoorvaurdhwareshe
# story_of_a_homemaker
# sonasfoodjournal
# dee.dee.eats
# pr.ateek518
# _food_stranger_
# zamirsohel
# narwade1722
# refreshyourlife.in
# the.kashmiri.kitchen
# chappandukan
# mr_rohit_6787
# keyvan_9675
# salkaracaterersekm
# rowdydivakarboss
# gauri20_
# hasanmahmud5986
# bartisans.in
# p_i_y_u__sh143
# st_its_me_the_hacker
# subhro_o_
# business_needs.official
# hungrytummy11
# talha.roshan.75
# its.goa
# newhomecuisine
# swapnilchandrabhushan
# nataliemankani
# bent_by_is
# purnima1096
# mr.devmohurle
# chef_pastry20
# all.about.fitness_byphysioneha
# beyond__the_plate
# manjukapoor55
# kami.ni496
# woman_like_me24
# nehanemani81
# ambitions_group226
# its__villen__186
# ...
